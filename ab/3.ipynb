# %%
from sklearn.datasets import fetch_california_housing
import seaborn as sns
import matplotlib.pyplot as plt

data = fetch_california_housing(as_frame=True, return_X_y=True)
df, target = data[0], data[1]

# %%
df['MedInc'].hist()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(df['MedInc'], kde=True, bins=50)
plt.title('MedInc')

plt.subplot(1,2,2)
sns.histplot(df['HouseAge'] / 5, kde=True, bins=50)
plt.title('HouseAge')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['MedInc'].mean() - df['MedInc'].median()
# Out:
# 0.3358710029070249

# %%
(df['HouseAge'].mean() - df['HouseAge'].median()) / 5
# Out:
# -0.07210271317829467

# %%
target.quantile([0.25, 0.75])
# Out:
# 0.25    1.19600
# 0.75    2.64725
# Name: MedHouseVal, dtype: float64

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
df
# Out:
# MedInc        0.688075
# HouseAge      0.105623
# AveRooms      0.151948
# AveBedrms    -0.046701
# Population   -0.024650
# AveOccup     -0.023737
# Latitude     -0.144160
# Longitude    -0.045967
# dtype: float64

# %%
df.corrwith(target)
# Out:
# MedInc        0.688075
# HouseAge      0.105623
# AveRooms      0.151948
# AveBedrms    -0.046701
# Population   -0.024650
# AveOccup     -0.023737
# Latitude     -0.144160
# Longitude    -0.045967
# dtype: float64

# %%
df.corrwith(target, method='spearman')
# Out:
# MedInc        0.676778
# HouseAge      0.074855
# AveRooms      0.263367
# AveBedrms    -0.125187
# Population    0.003839
# AveOccup     -0.256594
# Latitude     -0.165739
# Longitude    -0.069667
# dtype: float64

# %%
df.corrwith(target, method='kendall')
# Out:
# MedInc        0.495528
# HouseAge      0.049822
# AveRooms      0.179175
# AveBedrms    -0.083489
# Population    0.002172
# AveOccup     -0.174370
# Latitude     -0.109411
# Longitude    -0.052495
# dtype: float64

# %%
sns.histplot(df['AveRooms'], kde=True, bins=50)
plt.title('AveRooms')
# Out:
# Text(0.5, 1.0, 'AveRooms')

# %%
sns.heatmap(df.corr(), linewidths=0.1, vmax=1.0,
            square=True, annot=True)
# Out:
# <Axes: >

# %%
# standardization

scipy.stats.zscore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d7861f404895> in <module>
#       1 # standardization
#       2
# ----> 3 scipy.stats.zscore
#
# NameError: name 'scipy' is not defined
